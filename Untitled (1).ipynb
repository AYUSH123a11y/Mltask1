# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('gw1.csv')

# %%
data.head()
# Out:
#                         Country ISO2  F1961  F1962  F1963  F1964  F1965  \
# 0  Afghanistan, Islamic Rep. of   AF -0.113 -0.164  0.847 -0.764 -0.244
# 1                       Albania   AL  0.627  0.326  0.075 -0.166 -0.388
# 2                       Algeria   DZ  0.164  0.114  0.077  0.250 -0.100
# 3                American Samoa   AS  0.079 -0.042  0.169 -0.140 -0.562
# 4      Andorra, Principality of   AD  0.736  0.112 -0.752  0.308 -0.490
#
#    F1966  F1967  F1968  ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  \
# 0  0.226 -0.371 -0.423  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910
# 1  0.559 -0.074  0.081  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675
# 2  0.433 -0.026 -0.067  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115
# 3  0.181 -0.368 -0.187  ...  1.257  1.170  1.009  1.539  1.435  1.189  1.539
# 4  0.415  0.637  0.018  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964
#
#    F2020  F2021  F2022
# 0  0.498  1.327  2.012
# ...

# %%
data.shape
# Out:
# (181, 64)

# %%
data.columns
# Out:
# Index(['Country', 'ISO2', 'F1961', 'F1962', 'F1963', 'F1964', 'F1965', 'F1966',
#        'F1967', 'F1968', 'F1969', 'F1970', 'F1971', 'F1972', 'F1973', 'F1974',
#        'F1975', 'F1976', 'F1977', 'F1978', 'F1979', 'F1980', 'F1981', 'F1982',
#        'F1983', 'F1984', 'F1985', 'F1986', 'F1987', 'F1988', 'F1989', 'F1990',
#        'F1991', 'F1992', 'F1993', 'F1994', 'F1995', 'F1996', 'F1997', 'F1998',
#        'F1999', 'F2000', 'F2001', 'F2002', 'F2003', 'F2004', 'F2005', 'F2006',
#        'F2007', 'F2008', 'F2009', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014',
#        'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022'],
#       dtype='object')

# %%
ncd=data[['F1961', 'F1962', 'F1963', 'F1964', 'F1965', 'F1966',
       'F1967', 'F1968', 'F1969', 'F1970', 'F1971', 'F1972', 'F1973', 'F1974',
       'F1975', 'F1976', 'F1977', 'F1978', 'F1979', 'F1980', 'F1981', 'F1982',
       'F1983', 'F1984', 'F1985', 'F1986', 'F1987', 'F1988', 'F1989', 'F1990',
       'F1991', 'F1992', 'F1993', 'F1994', 'F1995', 'F1996', 'F1997', 'F1998',
       'F1999', 'F2000', 'F2001', 'F2002', 'F2003', 'F2004', 'F2005', 'F2006',
       'F2007', 'F2008', 'F2009', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014',
       'F2015', 'F2016', 'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']]

# %%
data['F1961']
# Out:
# 0     -0.113
# 1      0.627
# 2      0.164
# 3      0.079
# 4      0.736
#        ...
# 176   -0.110
# 177    0.632
# 178    0.211
# 179    0.228
# 180    0.267
# Name: F1961, Length: 181, dtype: float64

# %%
(data['F1961']>0).value_counts()
# Out:
# F1961
# True     106
# False     75
# Name: count, dtype: int64

# %%
a=(data['F1961']>0)

# %%
a
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 176    False
# 177     True
# 178     True
# 179     True
# 180     True
# Name: F1961, Length: 181, dtype: bool

# %%
x=data[a]

# %%
b=(data['F1961']<0)

# %%
b
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 176     True
# 177    False
# 178    False
# 179    False
# 180    False
# Name: F1961, Length: 181, dtype: bool

# %%
data.iloc[:,[0,2]]
# Out:
#                           Country  F1961
# 0    Afghanistan, Islamic Rep. of -0.113
# 1                         Albania  0.627
# 2                         Algeria  0.164
# 3                  American Samoa  0.079
# 4        Andorra, Principality of  0.736
# ..                            ...    ...
# 176            West Bank and Gaza -0.110
# 177                Western Sahara  0.632
# 178                         World  0.211
# 179                        Zambia  0.228
# 180                      Zimbabwe  0.267
#
# [181 rows x 2 columns]

# %%
data['F1961'].max()
# Out:
# 1.892

# %%
data['F1962'].max()
# Out:
# 0.998

# %%
data['F2022'].max()
# Out:
# 3.243

# %%
data.describe()
# Out:
#             F1961       F1962       F1963       F1964       F1965       F1966  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean     0.168829   -0.010934   -0.001066   -0.070768   -0.247564    0.121116
# std      0.406814    0.344845    0.389836    0.312151    0.269305    0.378343
# min     -0.694000   -0.908000   -1.270000   -0.877000   -1.064000   -1.801000
# 25%     -0.096000   -0.164000   -0.203000   -0.236000   -0.388000   -0.028000
# 50%      0.069000   -0.057000    0.009000   -0.052000   -0.230000    0.104000
# 75%      0.323000    0.114000    0.234000    0.130000   -0.090000    0.288000
# max      1.892000    0.998000    1.202000    1.097000    0.857000    1.151000
#
#             F1967       F1968       F1969       F1970  ...       F2013  \
# count  181.000000  181.000000  181.000000  181.000000  ...  181.000000
# mean    -0.108050   -0.203028    0.159823    0.088365  ...    0.884436
# ...

# %%
years=data.columns[2:64]
years
# Out:
# Index(['F1961', 'F1962', 'F1963', 'F1964', 'F1965', 'F1966', 'F1967', 'F1968',
#        'F1969', 'F1970', 'F1971', 'F1972', 'F1973', 'F1974', 'F1975', 'F1976',
#        'F1977', 'F1978', 'F1979', 'F1980', 'F1981', 'F1982', 'F1983', 'F1984',
#        'F1985', 'F1986', 'F1987', 'F1988', 'F1989', 'F1990', 'F1991', 'F1992',
#        'F1993', 'F1994', 'F1995', 'F1996', 'F1997', 'F1998', 'F1999', 'F2000',
#        'F2001', 'F2002', 'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008',
#        'F2009', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016',
#        'F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022'],
#       dtype='object')

# %%
means=data[years].mean()
data['Country'].unique()
# Out:
# array(['Afghanistan, Islamic Rep. of', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra, Principality of', 'Angola', 'Anguilla',
#        'Antigua and Barbuda', 'Argentina', 'Australia', 'Austria',
#        'Bahamas, The', 'Bahrain, Kingdom of', 'Bangladesh', 'Barbados',
#        'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada',
#        'Cayman Islands', 'Central African Rep.', 'Chad', 'Chile',
#        'China, P.R.: Hong Kong', 'China, P.R.: Macao',
#        'China, P.R.: Mainland', 'Colombia', 'Comoros, Union of the',
#        'Congo, Dem. Rep. of the', 'Congo, Rep. of', 'Cook Islands',
#        'Cuba', 'Cyprus', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Rep.', 'Ecuador', 'Egypt, Arab Rep. of', 'El Salvador',
#        'Equatorial Guinea, Rep. of', 'Eswatini, Kingdom of',
# ...

# %%
means
# Out:
# F1961    0.168829
# F1962   -0.010934
# F1963   -0.001066
# F1964   -0.070768
# F1965   -0.247564
#            ...
# F2018    1.199459
# F2019    1.375702
# F2020    1.459641
# F2021    1.322906
# F2022    1.294492
# Length: 62, dtype: float64

# %%
plt.figure(figsize=(10, 5))
plt.plot(years,means)
plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years')

plt.tight_layout()
plt.xticks(rotation=90)
plt.grid(True)

# %%
x1=(data[data['Country']=='Switzerland']).T.iloc[2:]    #europe             #developed
x2=data[data['Country']=='Japan'].T.iloc[2:]
x3=data[data['Country']=='Mauritius'].T.iloc[2:]    #africa


plt.figure(figsize=(10, 5))
plt.plot(years,x1,label='Switzerland',color='#7DDA58')
plt.plot(years,x2,label='Japan',color='#FFDE59')
plt.plot(years,x3,label='Mauritius',color='#CC3839')

plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Developed Country')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
y1=data[data['Country']=='India'].T.iloc[2:]                  #develpoing
y2=data[data['Country']=='Uganda'].T.iloc[2:]      #africa
y3=data[data['Country']=='Portugal'].T.iloc[2:]   #europe

plt.figure(figsize=(10, 5))
plt.plot(years,y1,label='India',color='#FE9900')
plt.plot(years,y2,label='Uganda',color='#F3AAB6')
plt.plot(years,y3,label='Portugal',color='#E0ECA0')

plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Developing Country')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
z1=data[data['Country']=='Bulgaria'].T.iloc[2:]      #europe     #underdevelpoed
z2=data[data['Country']=='Niger'].T.iloc[2:]         #africa
z3=data[data['Country']=='Bangladesh'].T.iloc[2:]


plt.figure(figsize=(10, 5))
plt.plot(years,z1,label='Bulgaria',color='#CC6CE7')
plt.plot(years,z2,label='Niger',color='#F27778')
plt.plot(years,z3,label='Bangladesh',color='#ECD2C8')

plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Underdevelpoed Country')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
x2=data[data['Country']=='Japan'].T.iloc[2:]
x22=data[data['Country']=='China, P.R.: Hong Kong'].T.iloc[2:]

y1=data[data['Country']=='India'].T.iloc[2:] 
y11=data[data['Country']=='China, P.R.: Mainland'].T.iloc[2:] 

z3=data[data['Country']=='Bangladesh'].T.iloc[2:]
z33=data[data['Country']=='Myanmar'].T.iloc[2:]
plt.figure(figsize=(10, 5))
plt.plot(years,x2,label='Japan',color='#FA0505')
plt.plot(years,x22,label='China, P.R.: Hong Kong',color='#F66F6F')
plt.plot(years,y1,label='India',linestyle='--',color='#49F904',)
plt.plot(years,y11,label='China, P.R.: Mainland',linestyle='--',color='#9DF67A')
plt.plot(years,z3,label='Bangladesh',linestyle=':',color='#A682FC',)
plt.plot(years,z33,label='Myanmar',linestyle=':',color='#C0ADF0',)
plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Develpoed,Developing,Underdeveloped Countries ASIA')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
x3=data[data['Country']=='Mauritius'].T.iloc[2:]
x30=data[data['Country']=='Seychelles'].T.iloc[2:]

y2=data[data['Country']=='Uganda'].T.iloc[2:]  
y20=data[data['Country']=='Kenya'].T.iloc[2:]  

z2=data[data['Country']=='Niger'].T.iloc[2:] 
z20=data[data['Country']=='Chad'].T.iloc[2:]
plt.figure(figsize=(10, 5))
plt.plot(years,x3,label='Mauritius',color='#FA0505')
plt.plot(years,x30,label='Seychelles',color='#FA0505')

plt.plot(years,y2,label='Uganda',linestyle='--',color='#49F904')
plt.plot(years,y20,label='Kenya',linestyle='--',color='#49F904')

plt.plot(years,z2,label='Niger',linestyle=':',color='#C0ADF0')
plt.plot(years,z20,label='Chad',linestyle=':',color='#C0ADF0')

plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Develpoed,Developing,Underdeveloped Countries of Africa')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
x1=(data[data['Country']=='Switzerland']).T.iloc[2:]
x300=data[data['Country']=='Norway'].T.iloc[2:]

y3=data[data['Country']=='Portugal'].T.iloc[2:]  
y200=data[data['Country']=='Romania'].T.iloc[2:]  

z1=data[data['Country']=='Bulgaria'].T.iloc[2:] 
z200=data[data['Country']=='Albania'].T.iloc[2:]
plt.figure(figsize=(10, 5))
plt.plot(years,x1,label='Switzerland',color='#FA0505')
plt.plot(years,x300,label='Norway',color='#FA0505')

plt.plot(years,y3,label='Portugal',linestyle='--',color='#49F904')
plt.plot(years,y200,label='Romania',linestyle='--',color='#49F904')

plt.plot(years,z1,label='Bulgaria',linestyle=':',color='#C0ADF0')
plt.plot(years,z200,label='Albania',linestyle=':',color='#C0ADF0')

plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Develpoed,Developing,Underdeveloped Countries of Europe')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
plt.figure(figsize=(10, 5))
plt.plot(years,x1,label='Germany',color='#6C6868')
plt.plot(years,x2,label='Japan',color='#393434')
plt.plot(years,x3,label='Mauritius',color='#4F4242')
plt.plot(years,y1,label='India',linestyle='--',color='#FD99A9',)
plt.plot(years,y2,label='Uganda',linestyle='--',color='#FF8396')
plt.plot(years,y3,label='Iraq',linestyle='--',color='#FF546F')
plt.plot(years,z1,label='Portugal',linestyle=':',color='#D9FC20')
plt.plot(years,z2,label='Niger',linestyle=':',color='#E6FC70')
plt.plot(years,z3,label='Bangladesh',linestyle=':',color='#98B012')
plt.xlabel('Year')
plt.ylabel('Mean of temp. variation')
plt.title('Temperature variation over years of Develpoed,Developing,Underdeveloped Countries')

plt.tight_layout()
plt.legend()
plt.xticks(rotation=90)
plt.grid(True)

# %%
pos=data[data['Country']=='Japan'].iloc[:,2:]>0
(data['F2002']>0).value_counts()
# Out:
# F2002
# True    181
# Name: count, dtype: int64

# %%
(data['F2003']>0).value_counts()
# Out:
# F2003
# True    181
# Name: count, dtype: int64

# %%
x=((data.iloc[1:,54:])>0)
for i in ['F2013', 'F2014', 'F2015', 'F2016','F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']:
    print(x[i].value_counts())
# Out:
# F2013
# True    180
# Name: count, dtype: int64
# F2014
# True     178
# False      2
# Name: count, dtype: int64
# F2015
# True     179
# False      1
# Name: count, dtype: int64
# F2016
# True    180
# Name: count, dtype: int64
# F2017
# True    180
# Name: count, dtype: int64
# F2018
# True    180
# Name: count, dtype: int64
# F2019
# True    180
# Name: count, dtype: int64
# F2020
# True    180
# Name: count, dtype: int64
# F2021
# True     177
# False      3
# Name: count, dtype: int64
# F2022
# True     178
# False      2
# Name: count, dtype: int64

# %%
x=((data.iloc[1:,40:])>0)
for i in  ['F2000','F2001', 'F2002', 'F2003', 'F2004', 'F2005', 'F2006', 'F2007', 'F2008','F2009', 'F2010', 'F2011', 'F2012', 'F2013', 'F2014', 'F2015', 'F2016','F2017', 'F2018', 'F2019', 'F2020', 'F2021', 'F2022']:
    print(x[i].value_counts())
# Out:
# F2000
# True     171
# False      9
# Name: count, dtype: int64
# F2001
# True     179
# False      1
# Name: count, dtype: int64
# F2002
# True    180
# Name: count, dtype: int64
# F2003
# True    180
# Name: count, dtype: int64
# F2004
# True     178
# False      2
# Name: count, dtype: int64
# F2005
# True    180
# Name: count, dtype: int64
# F2006
# True     177
# False      3
# Name: count, dtype: int64
# F2007
# True     178
# False      2
# Name: count, dtype: int64
# F2008
# True    180
# Name: count, dtype: int64
# F2009
# True     178
# False      2
# Name: count, dtype: int64
# F2010
# True     173
# False      7
# Name: count, dtype: int64
# F2011
# True     178
# False      2
# Name: count, dtype: int64
# F2012
# True     179
# False      1
# Name: count, dtype: int64
# F2013
# True    180
# Name: count, dtype: int64
# F2014
# True     178
# False      2
# Name: count, dtype: int64
# F2015
# True     179
# False      1
# Name: count, dtype: int64
# F2016
# True    180
# ...

# %%
x=((data.iloc[1:,2:])>0)
for i in  years:
    print(x[i].value_counts())
# Out:
# F1961
# True     106
# False     74
# Name: count, dtype: int64
# F1962
# False    113
# True      67
# Name: count, dtype: int64
# F1963
# True     90
# False    90
# Name: count, dtype: int64
# F1964
# False    105
# True      75
# Name: count, dtype: int64
# F1965
# False    158
# True      22
# Name: count, dtype: int64
# F1966
# True     122
# False     58
# Name: count, dtype: int64
# F1967
# False    133
# True      47
# Name: count, dtype: int64
# F1968
# False    149
# True      31
# Name: count, dtype: int64
# F1969
# True     131
# False     49
# Name: count, dtype: int64
# F1970
# True     122
# False     58
# Name: count, dtype: int64
# F1971
# False    157
# True      23
# Name: count, dtype: int64
# F1972
# False    107
# True      73
# Name: count, dtype: int64
# F1973
# True     138
# False     42
# Name: count, dtype: int64
# F1974
# False    141
# True      39
# Name: count, dtype: int64
# F1975
# False    118
# True      62
# Name: count, dtype: int64
# F1976
# ...

# %%
for i in range(1,181):
    print((data.iloc[i, 2:64]>0).value_counts())
# Out:
# 1
# True     40
# False    22
# Name: count, dtype: int64
# 2
# True     51
# False    11
# Name: count, dtype: int64
# 3
# True     50
# False    12
# Name: count, dtype: int64
# 4
# True     51
# False    11
# Name: count, dtype: int64
# 5
# True     49
# False    13
# Name: count, dtype: int64
# 6
# True     51
# False    11
# Name: count, dtype: int64
# 7
# True     51
# False    11
# Name: count, dtype: int64
# 8
# True     47
# False    15
# Name: count, dtype: int64
# 9
# True     52
# False    10
# Name: count, dtype: int64
# 10
# True     47
# False    15
# Name: count, dtype: int64
# 11
# True     50
# False    12
# Name: count, dtype: int64
# 12
# True     48
# False    14
# Name: count, dtype: int64
# 13
# True     39
# False    23
# Name: count, dtype: int64
# 14
# True     48
# False    14
# Name: count, dtype: int64
# 15
# True     48
# False    14
# Name: count, dtype: int64
# 16
# True     49
# False    13
# Name: count, dtype: int64
# 17
# True     43
# False    19
# ...

# %%
(data.iloc[:, 2:64].mean(axis=1))
# Out:
# 0      0.484661
# 1      0.471387
# 2      0.724871
# 3      0.521290
# 4      0.792806
#          ...
# 176    0.333419
# 177    0.805548
# 178    0.570774
# 179    0.403823
# 180    0.203677
# Length: 181, dtype: float64

# %%
(data.iloc[:, 2:64].mean(axis=1)).max()
# Out:
# 0.8955967741935484

# %%
rmean = data.iloc[:, 2:64].mean(axis=1)
indmin = rmean.idxmin()
min=rmean[indmin]
rowmin= data.loc[indmin]
print(rowmin)
min
# Out:
# Country    Cook Islands
# ISO2                 CK
# F1961             0.148
# F1962            -0.064
# F1963            -0.099
#                ...
# F2018             0.238
# F2019              0.22
# F2020             0.274
# F2021             0.568
# F2022             0.479
# Name: 40, Length: 64, dtype: object
# 0.13943548387096774

# %%
rmean = data.iloc[:, 2:64].mean(axis=1)
ind = rmean.idxmax()
max=rmean[ind]
rowm= data.loc[ind]
print(rowm)
max
# Out:
# Country    Mongolia
# ISO2             MN
# F1961          0.17
# F1962        -0.106
# F1963         1.202
#              ...
# F2018         2.207
# F2019         1.847
# F2020         2.353
# F2021         1.994
# F2022         2.197
# Name: 109, Length: 64, dtype: object
# 0.8955967741935484

# %%
data2 = pd.read_csv('co.csv', encoding='latin1')      # or 'latin1' or 'cp1252'

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59620 entries, 0 to 59619
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              59620 non-null  object
#  1   Code                 57452 non-null  object
#  2   Calling Code         56097 non-null  object
#  3   Year                 59620 non-null  int64
#  4   CO2 emission (Tons)  59620 non-null  float64
#  5   Population(2022)     53116 non-null  float64
#  6   Area                 55284 non-null  float64
#  7   % of World           55284 non-null  object
#  8   Density(km2)         53116 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.1+ MB

# %%
data2.describe()
# Out:
#                Year  CO2 emission (Tons)  Population(2022)          Area
# count  59620.000000         5.962000e+04      5.311600e+04  5.528400e+04
# mean    1885.000000         1.034774e+09      3.992260e+07  6.522073e+05
# std       78.231085         1.041652e+10      1.482365e+08  1.865483e+06
# min     1750.000000         0.000000e+00      1.131200e+04  2.100000e+01
# 25%     1817.000000         0.000000e+00      1.770414e+06  1.770450e+04
# 50%     1885.000000         0.000000e+00      8.673095e+06  1.103815e+05
# 75%     1953.000000         8.715092e+06      2.862920e+07  4.925730e+05
# max     2020.000000         4.170000e+11      1.425887e+09  1.709824e+07

# %%
data2.shape
# Out:
# (59620, 9)

# %%
data2.head()
# Out:
#        Country Code Calling Code  Year  CO2 emission (Tons)  Population(2022)  \
# 0  Afghanistan   AF           93  1750                  0.0        41128771.0
# 1  Afghanistan   AF           93  1751                  0.0        41128771.0
# 2  Afghanistan   AF           93  1752                  0.0        41128771.0
# 3  Afghanistan   AF           93  1753                  0.0        41128771.0
# 4  Afghanistan   AF           93  1754                  0.0        41128771.0
#
#        Area % of World Density(km2)
# 0  652230.0      0.40%       63/km²
# 1  652230.0      0.40%       63/km²
# 2  652230.0      0.40%       63/km²
# 3  652230.0      0.40%       63/km²
# 4  652230.0      0.40%       63/km²

# %%
data2.groupby('Country')

# %%
data2.groupby('Country')['Country'].count()
# Out:
# Country
# Afghanistan          271
# Albania              271
# Algeria              271
# Andorra              271
# Angola               271
#                     ...
# Vietnam              271
# Wallis and Futuna    271
# Yemen                271
# Zambia               271
# Zimbabwe             271
# Name: Country, Length: 220, dtype: int64

# %%
data2.dropna().shape
# Out:
# (48509, 9)

# %%
data2.dropna(inplace=True)

# %%
data2.count()
# Out:
# Country                48509
# Code                   48509
# Calling Code           48509
# Year                   48509
# CO2 emission (Tons)    48509
# Population(2022)       48509
# Area                   48509
# % of World             48509
# Density(km2)           48509
# dtype: int64

# %%
data2.head()
# Out:
#        Country Code Calling Code  Year  CO2 emission (Tons)  Population(2022)  \
# 0  Afghanistan   AF           93  1750                  0.0        41128771.0
# 1  Afghanistan   AF           93  1751                  0.0        41128771.0
# 2  Afghanistan   AF           93  1752                  0.0        41128771.0
# 3  Afghanistan   AF           93  1753                  0.0        41128771.0
# 4  Afghanistan   AF           93  1754                  0.0        41128771.0
#
#        Area % of World Density(km2)
# 0  652230.0      0.40%       63/km²
# 1  652230.0      0.40%       63/km²
# 2  652230.0      0.40%       63/km²
# 3  652230.0      0.40%       63/km²
# 4  652230.0      0.40%       63/km²

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48509 entries, 0 to 59619
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              48509 non-null  object
#  1   Code                 48509 non-null  object
#  2   Calling Code         48509 non-null  object
#  3   Year                 48509 non-null  int64
#  4   CO2 emission (Tons)  48509 non-null  float64
#  5   Population(2022)     48509 non-null  float64
#  6   Area                 48509 non-null  float64
#  7   % of World           48509 non-null  object
#  8   Density(km2)         48509 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.7+ MB

# %%
data2.describe()
# Out:
#                Year  CO2 emission (Tons)  Population(2022)          Area
# count  48509.000000         4.850900e+04      4.850900e+04  4.850900e+04
# mean    1885.000000         1.160748e+09      4.186199e+07  6.328071e+05
# std       78.231235         1.125903e+10      1.545682e+08  1.551563e+06
# min     1750.000000         0.000000e+00      1.131200e+04  2.100000e+01
# 25%     1817.000000         0.000000e+00      2.305825e+06  2.633800e+04
# 50%     1885.000000         0.000000e+00      9.038309e+06  1.303730e+05
# 75%     1953.000000         1.660158e+07      3.054758e+07  5.516950e+05
# max     2020.000000         4.170000e+11      1.425887e+09  9.984670e+06

# %%
data2['Country'].nunique()
# Out:
# 179

# %%
data2.columns
# Out:
# Index(['Country', 'Code', 'Calling Code', 'Year', 'CO2 emission (Tons)',
#        'Population(2022)', 'Area', '% of World', 'Density(km2)'],
#       dtype='object')

# %%
df_cleaned = data2[(data2 != 0).all(axis=1)]

# %%
df_cleaned.shape
# Out:
# (18746, 9)

# %%
df_cleaned.head()
# Out:
#          Country Code Calling Code  Year  CO2 emission (Tons)  \
# 199  Afghanistan   AF           93  1949              14656.0
# 200  Afghanistan   AF           93  1950              98928.0
# 201  Afghanistan   AF           93  1951             190528.0
# 202  Afghanistan   AF           93  1952             282128.0
# 203  Afghanistan   AF           93  1953             388384.0
#
#      Population(2022)      Area % of World Density(km2)
# 199        41128771.0  652230.0      0.40%       63/km²
# 200        41128771.0  652230.0      0.40%       63/km²
# 201        41128771.0  652230.0      0.40%       63/km²
# 202        41128771.0  652230.0      0.40%       63/km²
# 203        41128771.0  652230.0      0.40%       63/km²

# %%
df_cleaned.tail()
# Out:
#         Country Code Calling Code  Year  CO2 emission (Tons)  \
# 59615  Zimbabwe   ZW          263  2016          736467042.0
# 59616  Zimbabwe   ZW          263  2017          746048675.0
# 59617  Zimbabwe   ZW          263  2018          757903042.0
# 59618  Zimbabwe   ZW          263  2019          768852126.0
# 59619  Zimbabwe   ZW          263  2020          779383468.0
#
#        Population(2022)      Area % of World Density(km2)
# 59615        16320537.0  390757.0      0.30%       42/km²
# 59616        16320537.0  390757.0      0.30%       42/km²
# 59617        16320537.0  390757.0      0.30%       42/km²
# 59618        16320537.0  390757.0      0.30%       42/km²
# 59619        16320537.0  390757.0      0.30%       42/km²

# %%
df_cleaned.describe()
# Out:
#                Year  CO2 emission (Tons)  Population(2022)          Area
# count  18746.000000         1.874600e+04      1.874600e+04  1.874600e+04
# mean    1955.303798         3.003667e+09      5.276920e+07  8.206250e+05
# std       50.094779         1.795847e+10      1.786999e+08  1.937586e+06
# min     1750.000000         4.200000e+01      1.131200e+04  2.100000e+01
# 25%     1927.000000         5.079220e+06      3.684032e+06  4.522700e+04
# 50%     1967.000000         6.872360e+07      1.038497e+07  1.999510e+05
# 75%     1994.000000         6.943111e+08      3.845433e+07  5.803670e+05
# max     2020.000000         4.170000e+11      1.425887e+09  9.984670e+06

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18746 entries, 199 to 59619
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              18746 non-null  object
#  1   Code                 18746 non-null  object
#  2   Calling Code         18746 non-null  object
#  3   Year                 18746 non-null  int64
#  4   CO2 emission (Tons)  18746 non-null  float64
#  5   Population(2022)     18746 non-null  float64
#  6   Area                 18746 non-null  float64
#  7   % of World           18746 non-null  object
#  8   Density(km2)         18746 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
df_cleaned['Country'].value_counts()
# Out:
# Country
# United Kingdom      271
# Canada              236
# Germany             229
# Poland              221
# United States       221
#                    ...
# Mayotte              31
# Andorra              31
# Lesotho              31
# Micronesia           29
# Marshall Islands     29
# Name: count, Length: 179, dtype: int64

# %%
df_cleaned['Country'].nunique()
# Out:
# 179

# %%
df_cleaned[df_cleaned['Country']=='India']
# Out:
#       Country Code Calling Code  Year  CO2 emission (Tons)  Population(2022)  \
# 24227   India   IN           91  1858         3.950500e+05      1.417173e+09
# 24228   India   IN           91  1859         1.032441e+06      1.417173e+09
# 24229   India   IN           91  1860         1.676472e+06      1.417173e+09
# 24230   India   IN           91  1861         2.174434e+06      1.417173e+09
# 24231   India   IN           91  1862         2.725512e+06      1.417173e+09
# ...       ...  ...          ...   ...                  ...               ...
# 24385   India   IN           91  2016         4.431507e+10      1.417173e+09
# 24386   India   IN           91  2017         4.674892e+10      1.417173e+09
# 24387   India   IN           91  2018         4.934873e+10      1.417173e+09
# 24388   India   IN           91  2019         5.197470e+10      1.417173e+09
# 24389   India   IN           91  2020         5.441649e+10      1.417173e+09
#
#             Area % of World Density(km2)
# ...

# %%
a1=df_cleaned[df_cleaned['Country']=='Japan']['Year'].iloc[82:]
a2=df_cleaned[df_cleaned['Country']=='Singapore']['Year']
a3=df_cleaned[df_cleaned['Country']=='India']['Year'].iloc[92:]
a4=df_cleaned[df_cleaned['Country']=='China']['Year'].iloc[51:]
a5=df_cleaned[df_cleaned['Country']=='Bangladesh']['Year'].iloc[4:]
a6=df_cleaned[df_cleaned['Country']=='Myanmar']['Year'].iloc[22:]


af1=df_cleaned[df_cleaned['Country']=='Mauritius']['Year']
af2=df_cleaned[df_cleaned['Country']=='Seychelles']['Year']
af3=df_cleaned[df_cleaned['Country']=='Uganda']['Year']
af4=df_cleaned[df_cleaned['Country']=='Kenya']['Year']
af5=df_cleaned[df_cleaned['Country']=='Niger']['Year']
af6=df_cleaned[df_cleaned['Country']=='Chad']['Year']


e1=df_cleaned[df_cleaned['Country']=='Switzerland']['Year'].iloc[92:]
e2=df_cleaned[df_cleaned['Country']=='Norway']['Year'].iloc[121:]
e3=df_cleaned[df_cleaned['Country']=='Portugal']['Year'].iloc[80:]
e4=df_cleaned[df_cleaned['Country']=='Romania']['Year'].iloc[92:]
e5=df_cleaned[df_cleaned['Country']=='Bulgaria']['Year'].iloc[69:]
e6=df_cleaned[df_cleaned['Country']=='Albania']['Year'].iloc[17:]

# %%
ya1=df_cleaned[df_cleaned['Country']=='Japan']['CO2 emission (Tons)'].iloc[82:]
ya2=df_cleaned[df_cleaned['Country']=='Singapore']['CO2 emission (Tons)']
ya3=df_cleaned[df_cleaned['Country']=='India']['CO2 emission (Tons)'].iloc[92:]
ya4=df_cleaned[df_cleaned['Country']=='China']['CO2 emission (Tons)'].iloc[51:]
ya5=df_cleaned[df_cleaned['Country']=='Bangladesh']['CO2 emission (Tons)'].iloc[4:]
ya6=df_cleaned[df_cleaned['Country']=='Myanmar']['CO2 emission (Tons)'].iloc[22:]


yaf1=df_cleaned[df_cleaned['Country']=='Mauritius']['CO2 emission (Tons)']
yaf2=df_cleaned[df_cleaned['Country']=='Seychelles']['CO2 emission (Tons)']
yaf3=df_cleaned[df_cleaned['Country']=='Uganda']['CO2 emission (Tons)']
yaf4=df_cleaned[df_cleaned['Country']=='Kenya']['CO2 emission (Tons)']
yaf5=df_cleaned[df_cleaned['Country']=='Niger']['CO2 emission (Tons)']
yaf6=df_cleaned[df_cleaned['Country']=='Chad']['CO2 emission (Tons)']


ye1=df_cleaned[df_cleaned['Country']=='Switzerland']['CO2 emission (Tons)'].iloc[92:]
ye2=df_cleaned[df_cleaned['Country']=='Norway']['CO2 emission (Tons)'].iloc[121:]
ye3=df_cleaned[df_cleaned['Country']=='Portugal']['CO2 emission (Tons)'].iloc[80:]
ye4=df_cleaned[df_cleaned['Country']=='Romania']['CO2 emission (Tons)'].iloc[92:]
ye5=df_cleaned[df_cleaned['Country']=='Bulgaria']['CO2 emission (Tons)'].iloc[69:]
ye6=df_cleaned[df_cleaned['Country']=='Albania']['CO2 emission (Tons)'].iloc[17:]

# %%
plt.plot(a1,ya1,label='Japan')
plt.plot(af1,yaf1,label='Mauritius')
plt.plot(e1,ye1,label='Switzerland')
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of develpoed countries ')
plt.legend()
plt.show()

# %%
plt.plot(a3,ya3,label='India')
plt.plot(af3,yaf3,label='Uganda')
plt.plot(e3,ye3,label='Portugal')
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of develpoing ')
plt.legend()
plt.show()

# %%
plt.plot(a5,ya5,label='Bangladesh')
plt.plot(af5,yaf5,label='Niger')
plt.plot(e5,ye5,label='Bulgeria')
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of underdevelpoed ')
plt.legend()
plt.show()

# %%
plt.plot(a1,ya1,label='Japan',color="Green")
plt.plot(a2,ya2,label='Singapore',linestyle=':',color="Green")
plt.plot(a3,ya3,label='India',color="Orange")
plt.plot(a4,ya4,label='China',linestyle=':',color="Orange")
plt.plot(a5,ya5,label='Bangladesh',color="Red")
plt.plot(a6,ya6,label='Myanmar',linestyle=':',color="Red")
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of Asian develpoed develpong underdevelpoed countries')
plt.legend()
plt.show()

# %%
plt.plot(af1,yaf1,label='Mauritius',color="Green")
plt.plot(af2,yaf2,label='Seychelles',linestyle=':',color="Green")
plt.plot(af3,yaf3,label='Uganda',color="Orange")
plt.plot(af4,yaf4,label='Kenya',linestyle=':',color="Orange")
plt.plot(af5,yaf5,label='Niger',color="Red")
plt.plot(af6,yaf6,label='Chad',linestyle=':',color="Red")
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of African develpoed develpong underdevelpoed countries')
plt.legend()
plt.show()

# %%
plt.plot(e1,ye1,label='Switzerland ',color="Green")
plt.plot(e2,ye2,label='Norway',linestyle=':',color="Green")
plt.plot(e3,ye3,label='Portugal',color="Orange")
plt.plot(e4,ye4,label='Romania',linestyle=':',color="Orange")
plt.plot(e5,ye5,label='Bulgaria',color="Red")
plt.plot(e6,ye6,label='Albania',linestyle=':',color="Red")
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of European develpoed develpong underdevelpoed countries')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 7.5)) 
plt.plot(a1,ya1,label='Japan',color="#FF77B7")
plt.plot(a2,ya2,label='Singapore',color="#FFE700")
plt.plot(a3,ya3,label='India',color="#FEFFA7")
plt.plot(a4,ya4,label='China',color="#B6FFA1")
plt.plot(a5,ya5,label='Bangladesh',color="#00FF9C")
plt.plot(a6,ya6,label='Myanmar',color="#10375C")
plt.plot(af1,yaf1,label='Mauritius',color="#FF77B7",linestyle='--')
plt.plot(af2,yaf2,label='Seychelles',color="#FFE700",linestyle='--')
plt.plot(af3,yaf3,label='Uganda',color="#FEFFA7",linestyle='--')
plt.plot(af4,yaf4,label='Kenya',color="#B6FFA1",linestyle='--')
plt.plot(af5,yaf5,label='Niger',color="#00FF9C",linestyle='--')
plt.plot(af6,yaf6,label='Chad',color="#10375C",linestyle='--')
plt.plot(e1,ye1,label='Switzerland ',color="#FF77B7",linestyle=':')
plt.plot(e2,ye2,label='Norway',color="#FFE700",linestyle=':')
plt.plot(e3,ye3,label='Portugal',color="#FEFFA7",linestyle=':')
plt.plot(e4,ye4,label='Romania',color="#B6FFA1",linestyle=':')
plt.plot(e5,ye5,label='Bulgaria',color="#00FF9C",linestyle=':')
plt.plot(e6,ye6,label='Albania',color="#10375C",linestyle=':')
plt.yscale('log')
plt.xlabel('Years')
plt.ylabel('CO2 emission (Tons)')
plt.title('CO2 Emission by Year of  develpoed develpong underdevelpoed countries')
plt.legend(fontsize=7, loc='best')
plt.show()

# %%
df_cleaned.head()
# Out:
#          Country Code Calling Code  Year  CO2 emission (Tons)  \
# 199  Afghanistan   AF           93  1949              14656.0
# 200  Afghanistan   AF           93  1950              98928.0
# 201  Afghanistan   AF           93  1951             190528.0
# 202  Afghanistan   AF           93  1952             282128.0
# 203  Afghanistan   AF           93  1953             388384.0
#
#      Population(2022)      Area % of World Density(km2)
# 199        41128771.0  652230.0      0.40%       63/km²
# 200        41128771.0  652230.0      0.40%       63/km²
# 201        41128771.0  652230.0      0.40%       63/km²
# 202        41128771.0  652230.0      0.40%       63/km²
# 203        41128771.0  652230.0      0.40%       63/km²

# %%
df_cleaned['Population(2022)']
# Out:
# 199      41128771.0
# 200      41128771.0
# 201      41128771.0
# 202      41128771.0
# 203      41128771.0
#             ...
# 59615    16320537.0
# 59616    16320537.0
# 59617    16320537.0
# 59618    16320537.0
# 59619    16320537.0
# Name: Population(2022), Length: 18746, dtype: float64

# %%
indmin = df_cleaned['Population(2022)'].idxmin()
min=df_cleaned['Population(2022)'][indmin]
rowmin= data2.loc[indmin]
rowmin
# Out:
# Country                 Tuvalu
# Code                        TV
# Calling Code               688
# Year                      1990
# CO2 emission (Tons)    10992.0
# Population(2022)       11312.0
# Area                      26.0
# % of World               0.00%
# Density(km2)           435/km²
# Name: 55795, dtype: object

# %%
indmin = df_cleaned['CO2 emission (Tons)'].idxmin()
min=df_cleaned['CO2 emission (Tons)'][indmin]
rowmin= data2.loc[indmin]
rowmin
# Out:
# Country                  Armenia
# Code                          AM
# Calling Code                 374
# Year                        1830
# CO2 emission (Tons)         42.0
# Population(2022)       2780469.0
# Area                     29743.0
# % of World                 0.00%
# Density(km2)              93/km²
# Name: 2519, dtype: object

# %%
indmin = df_cleaned['Area'].idxmin()
min=df_cleaned['Area'][indmin]
rowmin= data2.loc[indmin]
rowmin
# Out:
# Country                  Nauru
# Code                        NR
# Calling Code               674
# Year                      1964
# CO2 emission (Tons)    29312.0
# Population(2022)       12668.0
# Area                      21.0
# % of World               0.00%
# Density(km2)           603/km²
# Name: 37070, dtype: object

# %%
indmin = df_cleaned['% of World'].idxmin()
min=df_cleaned['% of World'][indmin]
rowmin= data2.loc[indmin]
rowmin
# Out:
# Country                  Albania
# Code                          AL
# Calling Code                 355
# Year                        1933
# CO2 emission (Tons)       7328.0
# Population(2022)       2842321.0
# Area                     28748.0
# % of World                 0.00%
# Density(km2)              99/km²
# Name: 454, dtype: object

# %%
indmax = df_cleaned['Population(2022)'].idxmax()
max=df_cleaned['Population(2022)'][indmax]
rowmax= data2.loc[indmax]
rowmax
# Out:
# Country                       China
# Code                             CN
# Calling Code                     86
# Year                           1899
# CO2 emission (Tons)         95264.0
# Population(2022)       1425887337.0
# Area                      9706961.0
# % of World                    6.30%
# Density(km2)                147/km²
# Name: 10718, dtype: object

# %%
indmax = df_cleaned['CO2 emission (Tons)'].idxmax()
max=df_cleaned['CO2 emission (Tons)'][indmax]
rowmax= data2.loc[indmax]
rowmax
# Out:
# Country                 United States
# Code                               US
# Calling Code                        1
# Year                             2020
# CO2 emission (Tons)    417000000000.0
# Population(2022)          338289857.0
# Area                        9372610.0
# % of World                      6.10%
# Density(km2)                   36/km²
# Name: 57180, dtype: object

# %%
indmax = df_cleaned['Area'].idxmax()
max=df_cleaned['Area'][indmax]
rowmax= data2.loc[indmax]
rowmax
# Out:
# Country                    Canada
# Code                           CA
# Calling Code                    1
# Year                         1785
# CO2 emission (Tons)        3664.0
# Population(2022)       38454327.0
# Area                    9984670.0
# % of World                  6.10%
# Density(km2)                4/km²
# Name: 9249, dtype: object

# %%
indmax = df_cleaned['% of World'].idxmax()
max=df_cleaned['% of World'][indmax]
rowmax= data2.loc[indmax]
rowmax
# Out:
# Country                       China
# Code                             CN
# Calling Code                     86
# Year                           1899
# CO2 emission (Tons)         95264.0
# Population(2022)       1425887337.0
# Area                      9706961.0
# % of World                    6.30%
# Density(km2)                147/km²
# Name: 10718, dtype: object

# %%
y = ['China', 'Japan', 'Singapore', 'India', 'Bangladesh', 'Myanmar', 'Mauritius', 'Seychelles', 'Uganda', 'Kenya', 'Niger', 'Chad', 'Switzerland', 'Norway', 'Portugal', 'Romania', 'Bulgaria', 'Albania']

abc=df_cleaned[df_cleaned['Country'].isin(y)].groupby('Country')['CO2 emission (Tons)'].last()

# %%
plt.barh(abc.index, abc.values)
plt.xscale('log')
plt.title('Countries by CO2 Emisson(TONS)')
plt.xlabel('CO2 emission (Tons)')
plt.ylabel('Country')
# Out:
# Text(0, 0.5, 'Country')

# %%
population = [1425887000, 123951692, 5975689, 1417173000, 171186372, 54179306, 1299469, 107118, 47249585, 54027487, 26207977, 17723315, 8740472, 5434319, 10270865, 19659267, 6781953, 2842321]
plt.figure(figsize=(12, 10))
plt.barh(y, population)
plt.title('Countries by Population')
plt.xlabel('Population')
plt.ylabel('Country')
plt.xscale('log')
plt.show()

# %%
abcde = df_cleaned[df_cleaned['Country'].isin(y)].groupby('Country')['Area'].last()

abcdes = abcde.sort_values(ascending=False)
plt.barh(abcdes.index, abcdes.values)
plt.title('Countries by Area')
plt.xlabel('Area')
plt.ylabel('Country')
plt.xscale('log')
plt.show()

# %%
df_cleaned.groupby('Country')["Area"].last().sort_values()
# Out:
# Country
# Nauru                         21.0
# Tuvalu                        26.0
# Liechtenstein                160.0
# Marshall Islands             181.0
# Saint Kitts and Nevis        261.0
#                            ...
# Australia                7692024.0
# Brazil                   8515767.0
# United States            9372610.0
# China                    9706961.0
# Canada                   9984670.0
# Name: Area, Length: 179, dtype: float64

# %%
df_cleaned.groupby('Country')["Population(2022)"].last().sort_values()
# Out:
# Country
# Tuvalu              1.131200e+04
# Nauru               1.266800e+04
# Palau               1.805500e+04
# Liechtenstein       3.932700e+04
# Marshall Islands    4.156900e+04
#                         ...
# Pakistan            2.358249e+08
# Indonesia           2.755013e+08
# United States       3.382899e+08
# India               1.417173e+09
# China               1.425887e+09
# Name: Population(2022), Length: 179, dtype: float64

# %%
#it was found that maximum surface temperature was recorded in 2020
#temperature is increasing in order of continents Europe>Africa>Asia
#Temperature of develpoing underdevelpoed countries of asia and africa is increasing fastly than develpoed countries of both continents due to increased co2 emission and population 
#But for Europe temp of develpoed and develpoing countries is increasing faster than underdevelpoed countries
#after 1996 there is a decline in colder region country 
#approx 15 countries have equal duration of hot and cold region
#max value for temp is that for mongolia and least for cook island
#CO2 emissions not uniformly distributed
#china has max co2 emission area and population with#armenia( least co2 emission)#Tuvalu (least population)#nauru( min area)
#seychelles being the least co2 emission country least populated out of selected countries
